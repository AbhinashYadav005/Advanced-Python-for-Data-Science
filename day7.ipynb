# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from requests) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from requests) (2025.11.12)

# %%
import requests
from pprint import pprint
url = "https://jsonplaceholder.typicode.com/posts/1"

response = requests.get(url)
if response.status_code == 200:
    data = response.json()
    pprint(data)
else:
    print("Error :",response.status_code)
# Out:
# {'body': 'quia et suscipit\n'
#          'suscipit recusandae consequuntur expedita et cum\n'
#          'reprehenderit molestiae ut ut quas totam\n'
#          'nostrum rerum est autem sunt rem eveniet architecto',
#  'id': 1,
#  'title': 'sunt aut facere repellat provident occaecati excepturi optio '
#           'reprehenderit',
#  'userId': 1}

# %%
import requests
url = "https://jsonplaceholder.typicode.com/posts"
payload = {"title":"Test", "body":"Hello API", "userId":1}
response = requests.post(url, json=payload)
print(response.json())
# Out:
# The kernel failed to start due to the missing module 'imp'. Consider installing this module.
#
# Click <a href='https://aka.ms/kernelFailuresMissingModule'>here</a> for more info.

# %%
# !pip install zeep
# Out:
# Collecting zeep
#   Downloading zeep-4.3.2-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: attrs>=17.2.0 in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from zeep) (25.4.0)
# Collecting isodate>=0.5.4 (from zeep)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting lxml>=4.6.0 (from zeep)
#   Downloading lxml-6.0.2-cp314-cp314-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: platformdirs>=1.4.0 in c:\users\amrit\appdata\roaming\python\python314\site-packages (from zeep) (4.5.1)
# Requirement already satisfied: requests>=2.7.0 in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from zeep) (2.32.5)
# Collecting requests-toolbelt>=0.7.1 (from zeep)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests-file>=1.5.1 (from zeep)
#   Downloading requests_file-3.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pytz in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from zeep) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.7.0->zeep) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.7.0->zeep) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.7.0->zeep) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amrit\appdata\local\programs\python\python314\lib\site-packages (from requests>=2.7.0->zeep) (2025.11.12)
# Downloading zeep-4.3.2-py3-none-any.whl (101 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading lxml-6.0.2-cp314-cp314-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.1 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.1 MB 651.7 kB/s eta 0:00:06
#    ------- -------------------------------- 0.8/4.1 MB 726.7 kB/s eta 0:00:05
#    ------- -------------------------------- 0.8/4.1 MB 726.7 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.0/4.1 MB 694.2 kB/s eta 0:00:05
#    ---------- ----------------------------- 1.0/4.1 MB 694.2 kB/s eta 0:00:05
#    ------------ --------------------------- 1.3/4.1 MB 743.0 kB/s eta 0:00:04
#    --------------- ------------------------ 1.6/4.1 MB 792.8 kB/s eta 0:00:04
#    ----------------- ---------------------- 1.8/4.1 MB 817.4 kB/s eta 0:00:03
#    -------------------- ------------------- 2.1/4.1 MB 844.7 kB/s eta 0:00:03
#    -------------------- ------------------- 2.1/4.1 MB 844.7 kB/s eta 0:00:03
#    ----------------------- ---------------- 2.4/4.1 MB 847.3 kB/s eta 0:00:03
#    ----------------------- ---------------- 2.4/4.1 MB 847.3 kB/s eta 0:00:03
#    ----------------------- ---------------- 2.4/4.1 MB 847.3 kB/s eta 0:00:03
#    ------------------------- -------------- 2.6/4.1 MB 761.9 kB/s eta 0:00:02
#    ------------------------- -------------- 2.6/4.1 MB 761.9 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.9/4.1 MB 747.3 kB/s eta 0:00:02
#    ---------------------------- ----------- 2.9/4.1 MB 747.3 kB/s eta 0:00:02
#    ------------------------------ --------- 3.1/4.1 MB 736.4 kB/s eta 0:00:02
#    ------------------------------ --------- 3.1/4.1 MB 736.4 kB/s eta 0:00:02
#    --------------------------------- ------ 3.4/4.1 MB 709.7 kB/s eta 0:00:01
#    --------------------------------- ------ 3.4/4.1 MB 709.7 kB/s eta 0:00:01
#    ----------------------------------- ---- 3.7/4.1 MB 715.7 kB/s eta 0:00:01
#    ----------------------------------- ---- 3.7/4.1 MB 715.7 kB/s eta 0:00:01
#    -------------------------------------- - 3.9/4.1 MB 710.7 kB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 714.2 kB/s  0:00:05
# Downloading requests_file-3.0.1-py2.py3-none-any.whl (4.5 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Installing collected packages: lxml, isodate, requests-toolbelt, requests-file, zeep
#
#    ---------------------------------------- 0/5 [lxml]
#    ---------------- ----------------------- 2/5 [requests-toolbelt]
#    -------------------------------- ------- 4/5 [zeep]
#    -------------------------------- ------- 4/5 [zeep]
#    ---------------------------------------- 5/5 [zeep]
#
# Successfully installed isodate-0.7.2 lxml-6.0.2 requests-file-3.0.1 requests-toolbelt-1.0.0 zeep-4.3.2

# %%
from zeep import Client

wsdl = "http://www.dneonline.com/calculator.asmx?WSDL"
client = Client(wsdl=wsdl)

result = client.service.Add(10, 20)
print(result)
# Out:
# 30
